# %% [raw]
# ---
# {}
#
# ---

# %%
mq_evidence = "../../test_data/system_tests/organellar_maps/evidence.txt"
mq_protein_groups = "../../test_data/system_tests/organellar_maps/proteinGroups.txt"

directlfq_table = "../../test_data/system_tests/organellar_maps/evidence.txt.protgroup_annotated.tsv.protein_intensities.tsv"

merged_table = "../../test_data/system_tests/organellar_maps/directLFQ_in_proteingroupstxt_format.txt"

# %%
if False:
    import directlfq.lfq_manager as lfq_manager

    lfq_manager.run_lfq(input_file=mq_evidence, input_type_to_use="maxquant_evidence", mq_protein_groups_txt=mq_protein_groups, columns_to_add=None)

# %%
#merge with relevant proteinGroups data
import pandas as pd

df_mq = pd.read_csv(mq_protein_groups, sep = "\t")
df_directlfq = pd.read_csv(directlfq_table, sep = "\t")
df_directlfq = df_directlfq.drop(columns=["Protein IDs", "Gene names"])

cols_to_drop = [x for x in df_mq.columns if "LFQ intensity" in x]

df_mq_subset = df_mq.drop(columns = cols_to_drop)
df_mq_subset = df_mq_subset.astype({'id' : 'str'})
# Out:
# /var/folders/wb/j08kzzbd2hd8838tn3ll0jfm0000gn/T/ipykernel_8042/1669023202.py:4: DtypeWarning: Columns (221) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_mq = pd.read_csv(mq_protein_groups, sep = "\t")

# %%
from matplotlib.pyplot import axis
import numpy as np

df_merged = df_directlfq.merge(right=df_mq_subset, left_on="protein", right_on='Protein IDs', how='outer')
quant_columns = [x for x in df_directlfq.columns if "Map" in x and not "MS/MS" in x]

df_merged[quant_columns] = df_merged[quant_columns].replace(np.nan, 0)
for col in quant_columns:
    df_merged[col] = df_merged[col].astype('int64')
rename_dict = {x : "LFQ intensity " + x for x in quant_columns}
df_merged = df_merged.rename(columns = rename_dict)
protein_cols = [x for x in df_merged.columns if "Protein" in x]

df_merged = df_merged.drop(columns = ["Unnamed: 0", "protein"])

df_merged.to_csv(merged_table, sep="\t", index=None)
# Out:
#       Unnamed: 0                                            protein  \
# 0            0.0                                         A0A096LP01
# 1            1.0                                         A0A0B4J2F0
# 2            2.0  A0AV96;A0AV96-2;Q9NQ94-5;Q9NQ94-6;Q9NQ94-3;Q9N...
# 3            3.0                           A0AVF1-2;A0AVF1;A0AVF1-3
# 4            4.0                  A0AVT1;A0AVT1-2;A0AVT1-3;A0AVT1-4
# ...          ...                                                ...
# 7428         NaN                                                NaN
# 7429         NaN                                                NaN
# 7430         NaN                                                NaN
# 7431         NaN                                                NaN
# 7432         NaN                                                NaN
#
#       LFQ intensity Map1_12K  LFQ intensity Map1_1K  LFQ intensity Map1_24K  \
# 0                          0               65025258                       0
# 1                          0                      0                       0
# 2                 1452292237             1518727151              2243505256
# 3                          0                      0                       0
# 4                  523870779             1000353554               302421684
# ...                      ...                    ...                     ...
# 7428                       0                      0                       0
# 7429                       0                      0                       0
# 7430                       0                      0                       0
# 7431                       0                      0                       0
# 7432                       0                      0                       0
#
#       LFQ intensity Map1_3K  LFQ intensity Map1_6K  LFQ intensity Map1_80K  \
# 0                 294122443              247092114                       0
# 1                 236610394              180017634                       0
# 2                         0             1332728507              2722826180
# 3                         0                      0                       0
# 4                         0                      0                       0
# ...                     ...                    ...                     ...
# 7428                      0                      0                       0
# 7429                      0                      0                       0
# 7430                      0                      0                       0
# 7431                      0                      0                       0
# 7432                      0                      0                       0
#
#       LFQ intensity Map1_Cyt  LFQ intensity Map2_12K  ...  \
# 0                          0                       0  ...
# 1                          0                       0  ...
# 2                  470484030              1718004157  ...
# 3                          0                       0  ...
# 4                 3055834665               468651344  ...
# ...                      ...                     ...  ...
# 7428                       0                       0  ...
# 7429                       0                       0  ...
# 7430                       0                       0  ...
# 7431                       0                       0  ...
# 7432                       0                       0  ...
#
#       Potential contaminant    id  \
# 0                       NaN     0
# 1                       NaN     2
# 2                       NaN     3
# 3                       NaN     4
# 4                       NaN     5
# ...                     ...   ...
# 7428                    NaN  7403
# 7429                    NaN  7410
# 7430                    NaN  7412
# 7431                    NaN  7417
# 7432                    NaN  7429
#
#                                             Peptide IDs  \
# 0                                           11268;16295
# 1                                                 56662
# 2     15025;16215;19649;27765;28539;32746;32789;3966...
# 3                         12225;32711;48394;66252;66376
# 4     1170;3836;4957;8563;10264;16293;18501;23960;24...
# ...                                                 ...
# 7428                                              37463
# 7429                                              44471
# 7430                                              45094
# 7431                                              65122
# 7432                                              65322
#
#                                        Peptide is razor  \
# 0                                             True;True
# 1                                                  True
# 2     True;True;True;True;True;True;True;True;True;T...
# 3                              True;True;True;True;True
# 4     True;True;True;True;True;True;True;True;True;T...
# ...                                                 ...
# 7428                                               True
# 7429                                               True
# 7430                                               True
# 7431                                               True
# 7432                                               True
#
#                                        Mod. peptide IDs  \
# 0                                           12118;17534
# 1                                                 61531
# 2     16186;17452;21123;29904;30735;35225;35268;4264...
# 3                         13141;35190;51940;72030;72165
# 4     1257;4125;5328;9252;11049;17532;19900;25791;26...
# ...                                                 ...
# 7428                                              40214
# 7429                                              47757
# 7430                                              48421
# 7431                                              70848
# 7432                                              71069
#
#                                            Evidence IDs  \
# 0     114025;114026;114027;114028;114029;114030;1140...
# 1      586812;586813;586814;586815;586816;586817;586818
# 2     154075;154076;154077;154078;154079;154080;1664...
# 3     125066;125067;125068;332816;332817;500824;5008...
# 4     12354;12355;12356;40193;40194;40195;52116;5211...
# ...                                                 ...
# 7428                                             384656
# 7429                                             460345
# 7430                                      466873;466874
# 7431                                             668551
# 7432                                      669898;669899
#
#                                               MS/MS IDs  \
# 0     103999;104000;104001;104002;104003;104004;1040...
# 1      535881;535882;535883;535884;535885;535886;535887
# 2     140271;140272;140273;140274;140275;151525;1515...
# 3      113910;303770;303771;458020;617902;619151;619152
# 4     11465;11466;11467;36912;36913;36914;47718;4771...
# ...                                                 ...
# 7428                                             351471
# 7429                                             420675
# 7430                                      426631;426632
# 7431                                             610330
# 7432                                      611511;611512
#
#                                              Best MS/MS  \
# 0                                         103999;152163
# 1                                                535886
# 2     140271;151525;181991;255805;262898;304290;3047...
# 3                    113910;303770;458020;617902;619152
# 4     11465;36914;47718;80796;94362;152160;171881;21...
# ...                                                 ...
# 7428                                             351471
# 7429                                             420675
# 7430                                             426632
# 7431                                             610330
# 7432                                             611511
#
#       Oxidation (M) site IDs    Oxidation (M) site positions
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        2;3                          39;455
# 3                        NaN                             NaN
# 4          4;5;6;7;8;9;10;11  56;162;492;872;909;985;992;998
# ...                      ...                             ...
# 7428                    7557                             185
# 7429                    7562                             173
# 7430                    7563                             188
# 7431                    7567                              76
# 7432                    7579                             488
#
# [7433 rows x 234 columns]
# ['Protein IDs', 'Protein names']
#       LFQ intensity Map1_12K  LFQ intensity Map1_1K  LFQ intensity Map1_24K  \
# 0                          0               65025258                       0
# 1                          0                      0                       0
# 2                 1452292237             1518727151              2243505256
# 3                          0                      0                       0
# 4                  523870779             1000353554               302421684
# ...                      ...                    ...                     ...
# 7428                       0                      0                       0
# 7429                       0                      0                       0
# 7430                       0                      0                       0
# 7431                       0                      0                       0
# 7432                       0                      0                       0
#
#       LFQ intensity Map1_3K  LFQ intensity Map1_6K  LFQ intensity Map1_80K  \
# 0                 294122443              247092114                       0
# 1                 236610394              180017634                       0
# 2                         0             1332728507              2722826180
# 3                         0                      0                       0
# 4                         0                      0                       0
# ...                     ...                    ...                     ...
# 7428                      0                      0                       0
# 7429                      0                      0                       0
# 7430                      0                      0                       0
# 7431                      0                      0                       0
# 7432                      0                      0                       0
#
#       LFQ intensity Map1_Cyt  LFQ intensity Map2_12K  LFQ intensity Map2_1K  \
# 0                          0                       0               76430744
# 1                          0                       0               55248669
# 2                  470484030              1718004157             1448909585
# 3                          0                       0                      0
# 4                 3055834665               468651344             1919603428
# ...                      ...                     ...                    ...
# 7428                       0                       0                      0
# 7429                       0                       0                      0
# 7430                       0                       0                      0
# 7431                       0                       0                      0
# 7432                       0                       0                      0
#
#       LFQ intensity Map2_24K  ...  Potential contaminant    id  \
# 0                          0  ...                    NaN     0
# 1                          0  ...                    NaN     2
# 2                 2221037363  ...                    NaN     3
# 3                          0  ...                    NaN     4
# 4                  424323685  ...                    NaN     5
# ...                      ...  ...                    ...   ...
# 7428                       0  ...                    NaN  7403
# 7429                       0  ...                    NaN  7410
# 7430                       0  ...                    NaN  7412
# 7431                       0  ...                    NaN  7417
# 7432                       0  ...                    NaN  7429
#
#                                             Peptide IDs  \
# 0                                           11268;16295
# 1                                                 56662
# 2     15025;16215;19649;27765;28539;32746;32789;3966...
# 3                         12225;32711;48394;66252;66376
# 4     1170;3836;4957;8563;10264;16293;18501;23960;24...
# ...                                                 ...
# 7428                                              37463
# 7429                                              44471
# 7430                                              45094
# 7431                                              65122
# 7432                                              65322
#
#                                        Peptide is razor  \
# 0                                             True;True
# 1                                                  True
# 2     True;True;True;True;True;True;True;True;True;T...
# 3                              True;True;True;True;True
# 4     True;True;True;True;True;True;True;True;True;T...
# ...                                                 ...
# 7428                                               True
# 7429                                               True
# 7430                                               True
# 7431                                               True
# 7432                                               True
#
#                                        Mod. peptide IDs  \
# 0                                           12118;17534
# 1                                                 61531
# 2     16186;17452;21123;29904;30735;35225;35268;4264...
# 3                         13141;35190;51940;72030;72165
# 4     1257;4125;5328;9252;11049;17532;19900;25791;26...
# ...                                                 ...
# 7428                                              40214
# 7429                                              47757
# 7430                                              48421
# 7431                                              70848
# 7432                                              71069
#
#                                            Evidence IDs  \
# 0     114025;114026;114027;114028;114029;114030;1140...
# 1      586812;586813;586814;586815;586816;586817;586818
# 2     154075;154076;154077;154078;154079;154080;1664...
# 3     125066;125067;125068;332816;332817;500824;5008...
# 4     12354;12355;12356;40193;40194;40195;52116;5211...
# ...                                                 ...
# 7428                                             384656
# 7429                                             460345
# 7430                                      466873;466874
# 7431                                             668551
# 7432                                      669898;669899
#
#                                               MS/MS IDs  \
# 0     103999;104000;104001;104002;104003;104004;1040...
# 1      535881;535882;535883;535884;535885;535886;535887
# 2     140271;140272;140273;140274;140275;151525;1515...
# 3      113910;303770;303771;458020;617902;619151;619152
# 4     11465;11466;11467;36912;36913;36914;47718;4771...
# ...                                                 ...
# 7428                                             351471
# 7429                                             420675
# 7430                                      426631;426632
# 7431                                             610330
# 7432                                      611511;611512
#
#                                              Best MS/MS  \
# 0                                         103999;152163
# 1                                                535886
# 2     140271;151525;181991;255805;262898;304290;3047...
# 3                    113910;303770;458020;617902;619152
# 4     11465;36914;47718;80796;94362;152160;171881;21...
# ...                                                 ...
# 7428                                             351471
# 7429                                             420675
# 7430                                             426632
# 7431                                             610330
# 7432                                             611511
#
#       Oxidation (M) site IDs    Oxidation (M) site positions
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        2;3                          39;455
# 3                        NaN                             NaN
# 4          4;5;6;7;8;9;10;11  56;162;492;872;909;985;992;998
# ...                      ...                             ...
# 7428                    7557                             185
# 7429                    7562                             173
# 7430                    7563                             188
# 7431                    7567                              76
# 7432                    7579                             488
#
# [7433 rows x 232 columns]

# %%
#show which columns are extra
#df_merged = pd.read_csv(merged_table, sep = "\t")
display(df_merged)
display(set(df_merged.columns).difference(set(df_mq.columns)))
display(set(df_mq.columns).difference(set(df_merged.columns)))
display(set(df_merged.columns).intersection(set(df_mq.columns)))
# Out:
#       LFQ intensity Map1_12K  LFQ intensity Map1_1K  LFQ intensity Map1_24K  \
# 0                          0               65025258                       0
# 1                          0                      0                       0
# 2                 1452292237             1518727151              2243505256
# 3                          0                      0                       0
# 4                  523870779             1000353554               302421684
# ...                      ...                    ...                     ...
# 7428                       0                      0                       0
# 7429                       0                      0                       0
# 7430                       0                      0                       0
# 7431                       0                      0                       0
# 7432                       0                      0                       0
#
#       LFQ intensity Map1_3K  LFQ intensity Map1_6K  LFQ intensity Map1_80K  \
# 0                 294122443              247092114                       0
# 1                 236610394              180017634                       0
# 2                         0             1332728507              2722826180
# 3                         0                      0                       0
# 4                         0                      0                       0
# ...                     ...                    ...                     ...
# 7428                      0                      0                       0
# 7429                      0                      0                       0
# 7430                      0                      0                       0
# 7431                      0                      0                       0
# 7432                      0                      0                       0
#
#       LFQ intensity Map1_Cyt  LFQ intensity Map2_12K  LFQ intensity Map2_1K  \
# 0                          0                       0               76430744
# 1                          0                       0               55248669
# 2                  470484030              1718004157             1448909585
# 3                          0                       0                      0
# 4                 3055834665               468651344             1919603428
# ...                      ...                     ...                    ...
# 7428                       0                       0                      0
# 7429                       0                       0                      0
# 7430                       0                       0                      0
# 7431                       0                       0                      0
# 7432                       0                       0                      0
#
#       LFQ intensity Map2_24K  ...  Potential contaminant    id  \
# 0                          0  ...                    NaN     0
# 1                          0  ...                    NaN     2
# 2                 2221037363  ...                    NaN     3
# 3                          0  ...                    NaN     4
# 4                  424323685  ...                    NaN     5
# ...                      ...  ...                    ...   ...
# 7428                       0  ...                    NaN  7403
# 7429                       0  ...                    NaN  7410
# 7430                       0  ...                    NaN  7412
# 7431                       0  ...                    NaN  7417
# 7432                       0  ...                    NaN  7429
#
#                                             Peptide IDs  \
# 0                                           11268;16295
# 1                                                 56662
# 2     15025;16215;19649;27765;28539;32746;32789;3966...
# 3                         12225;32711;48394;66252;66376
# 4     1170;3836;4957;8563;10264;16293;18501;23960;24...
# ...                                                 ...
# 7428                                              37463
# 7429                                              44471
# 7430                                              45094
# 7431                                              65122
# 7432                                              65322
#
#                                        Peptide is razor  \
# 0                                             True;True
# 1                                                  True
# 2     True;True;True;True;True;True;True;True;True;T...
# 3                              True;True;True;True;True
# 4     True;True;True;True;True;True;True;True;True;T...
# ...                                                 ...
# 7428                                               True
# 7429                                               True
# 7430                                               True
# 7431                                               True
# 7432                                               True
#
#                                        Mod. peptide IDs  \
# 0                                           12118;17534
# 1                                                 61531
# 2     16186;17452;21123;29904;30735;35225;35268;4264...
# 3                         13141;35190;51940;72030;72165
# 4     1257;4125;5328;9252;11049;17532;19900;25791;26...
# ...                                                 ...
# 7428                                              40214
# 7429                                              47757
# 7430                                              48421
# 7431                                              70848
# 7432                                              71069
#
#                                            Evidence IDs  \
# 0     114025;114026;114027;114028;114029;114030;1140...
# 1      586812;586813;586814;586815;586816;586817;586818
# 2     154075;154076;154077;154078;154079;154080;1664...
# 3     125066;125067;125068;332816;332817;500824;5008...
# 4     12354;12355;12356;40193;40194;40195;52116;5211...
# ...                                                 ...
# 7428                                             384656
# 7429                                             460345
# 7430                                      466873;466874
# 7431                                             668551
# 7432                                      669898;669899
#
#                                               MS/MS IDs  \
# 0     103999;104000;104001;104002;104003;104004;1040...
# 1      535881;535882;535883;535884;535885;535886;535887
# 2     140271;140272;140273;140274;140275;151525;1515...
# 3      113910;303770;303771;458020;617902;619151;619152
# 4     11465;11466;11467;36912;36913;36914;47718;4771...
# ...                                                 ...
# 7428                                             351471
# 7429                                             420675
# 7430                                      426631;426632
# 7431                                             610330
# 7432                                      611511;611512
#
#                                              Best MS/MS  \
# 0                                         103999;152163
# 1                                                535886
# 2     140271;151525;181991;255805;262898;304290;3047...
# 3                    113910;303770;458020;617902;619152
# 4     11465;36914;47718;80796;94362;152160;171881;21...
# ...                                                 ...
# 7428                                             351471
# 7429                                             420675
# 7430                                             426632
# 7431                                             610330
# 7432                                             611511
#
#       Oxidation (M) site IDs    Oxidation (M) site positions
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        2;3                          39;455
# 3                        NaN                             NaN
# 4          4;5;6;7;8;9;10;11  56;162;492;872;909;985;992;998
# ...                      ...                             ...
# 7428                    7557                             185
# 7429                    7562                             173
# 7430                    7563                             188
# 7431                    7567                              76
# 7432                    7579                             488
#
# [7433 rows x 232 columns]
# set()
# set()
# {'Best MS/MS',
#  'Evidence IDs',
#  'Fasta headers',
#  'Fraction 11',
#  'Fraction 21',
#  'Fraction 31',
#  'Fraction 41',
#  'Fraction 51',
#  'Fraction 61',
#  'Fraction 71',
#  'Fraction average',
#  'Gene names',
#  'Identification type Map1_12K',
#  'Identification type Map1_1K',
#  'Identification type Map1_24K',
#  'Identification type Map1_3K',
#  'Identification type Map1_6K',
#  'Identification type Map1_80K',
#  'Identification type Map1_Cyt',
#  'Identification type Map2_12K',
#  'Identification type Map2_1K',
#  'Identification type Map2_24K',
#  'Identification type Map2_3K',
#  'Identification type Map2_6K',
#  'Identification type Map2_80K',
#  'Identification type Map2_Cyt',
#  'Identification type Map3_12K',
#  'Identification type Map3_1K',
#  'Identification type Map3_24K',
#  'Identification type Map3_3K',
#  'Identification type Map3_6K',
#  'Identification type Map3_80K',
#  'Identification type Map3_Cyt',
#  'Intensity',
#  'Intensity Map1_12K',
#  'Intensity Map1_1K',
#  'Intensity Map1_24K',
#  'Intensity Map1_3K',
#  'Intensity Map1_6K',
#  'Intensity Map1_80K',
#  'Intensity Map1_Cyt',
#  'Intensity Map2_12K',
#  'Intensity Map2_1K',
#  'Intensity Map2_24K',
#  'Intensity Map2_3K',
#  'Intensity Map2_6K',
#  'Intensity Map2_80K',
#  'Intensity Map2_Cyt',
#  'Intensity Map3_12K',
#  'Intensity Map3_1K',
#  'Intensity Map3_24K',
#  'Intensity Map3_3K',
#  'Intensity Map3_6K',
#  'Intensity Map3_80K',
#  'Intensity Map3_Cyt',
#  'LFQ intensity Map1_12K',
#  'LFQ intensity Map1_1K',
#  'LFQ intensity Map1_24K',
#  'LFQ intensity Map1_3K',
#  'LFQ intensity Map1_6K',
#  'LFQ intensity Map1_80K',
#  'LFQ intensity Map1_Cyt',
#  'LFQ intensity Map2_12K',
#  'LFQ intensity Map2_1K',
#  'LFQ intensity Map2_24K',
#  'LFQ intensity Map2_3K',
#  'LFQ intensity Map2_6K',
#  'LFQ intensity Map2_80K',
#  'LFQ intensity Map2_Cyt',
#  'LFQ intensity Map3_12K',
#  'LFQ intensity Map3_1K',
#  'LFQ intensity Map3_24K',
#  'LFQ intensity Map3_3K',
#  'LFQ intensity Map3_6K',
#  'LFQ intensity Map3_80K',
#  'LFQ intensity Map3_Cyt',
#  'MS/MS IDs',
#  'MS/MS count',
#  'MS/MS count Map1_12K',
#  'MS/MS count Map1_1K',
#  'MS/MS count Map1_24K',
#  'MS/MS count Map1_3K',
#  'MS/MS count Map1_6K',
#  'MS/MS count Map1_80K',
#  'MS/MS count Map1_Cyt',
#  'MS/MS count Map2_12K',
#  'MS/MS count Map2_1K',
#  'MS/MS count Map2_24K',
#  'MS/MS count Map2_3K',
#  'MS/MS count Map2_6K',
#  'MS/MS count Map2_80K',
#  'MS/MS count Map2_Cyt',
#  'MS/MS count Map3_12K',
#  'MS/MS count Map3_1K',
#  'MS/MS count Map3_24K',
#  'MS/MS count Map3_3K',
#  'MS/MS count Map3_6K',
#  'MS/MS count Map3_80K',
#  'MS/MS count Map3_Cyt',
#  'Majority protein IDs',
#  'Mod. peptide IDs',
#  'Mol. weight [kDa]',
#  'Number of proteins',
#  'Only identified by site',
#  'Oxidation (M) site IDs',
#  'Oxidation (M) site positions',
#  'Peptide IDs',
#  'Peptide counts (all)',
#  'Peptide counts (razor+unique)',
#  'Peptide counts (unique)',
#  'Peptide is razor',
#  'Peptides',
#  'Peptides Map1_12K',
#  'Peptides Map1_1K',
#  'Peptides Map1_24K',
#  'Peptides Map1_3K',
#  'Peptides Map1_6K',
#  'Peptides Map1_80K',
#  'Peptides Map1_Cyt',
#  'Peptides Map2_12K',
#  'Peptides Map2_1K',
#  'Peptides Map2_24K',
#  'Peptides Map2_3K',
#  'Peptides Map2_6K',
#  'Peptides Map2_80K',
#  'Peptides Map2_Cyt',
#  'Peptides Map3_12K',
#  'Peptides Map3_1K',
#  'Peptides Map3_24K',
#  'Peptides Map3_3K',
#  'Peptides Map3_6K',
#  'Peptides Map3_80K',
#  'Peptides Map3_Cyt',
#  'Potential contaminant',
#  'Protein IDs',
#  'Protein names',
#  'Q-value',
#  'Razor + unique peptides',
#  'Razor + unique peptides Map1_12K',
#  'Razor + unique peptides Map1_1K',
#  'Razor + unique peptides Map1_24K',
#  'Razor + unique peptides Map1_3K',
#  'Razor + unique peptides Map1_6K',
#  'Razor + unique peptides Map1_80K',
#  'Razor + unique peptides Map1_Cyt',
#  'Razor + unique peptides Map2_12K',
#  'Razor + unique peptides Map2_1K',
#  'Razor + unique peptides Map2_24K',
#  'Razor + unique peptides Map2_3K',
#  'Razor + unique peptides Map2_6K',
#  'Razor + unique peptides Map2_80K',
#  'Razor + unique peptides Map2_Cyt',
#  'Razor + unique peptides Map3_12K',
#  'Razor + unique peptides Map3_1K',
#  'Razor + unique peptides Map3_24K',
#  'Razor + unique peptides Map3_3K',
#  'Razor + unique peptides Map3_6K',
#  'Razor + unique peptides Map3_80K',
#  'Razor + unique peptides Map3_Cyt',
#  'Reverse',
#  'Score',
#  'Sequence coverage Map1_12K [%]',
#  'Sequence coverage Map1_1K [%]',
#  'Sequence coverage Map1_24K [%]',
#  'Sequence coverage Map1_3K [%]',
#  'Sequence coverage Map1_6K [%]',
#  'Sequence coverage Map1_80K [%]',
#  'Sequence coverage Map1_Cyt [%]',
#  'Sequence coverage Map2_12K [%]',
#  'Sequence coverage Map2_1K [%]',
#  'Sequence coverage Map2_24K [%]',
#  'Sequence coverage Map2_3K [%]',
#  'Sequence coverage Map2_6K [%]',
#  'Sequence coverage Map2_80K [%]',
#  'Sequence coverage Map2_Cyt [%]',
#  'Sequence coverage Map3_12K [%]',
#  'Sequence coverage Map3_1K [%]',
#  'Sequence coverage Map3_24K [%]',
#  'Sequence coverage Map3_3K [%]',
#  'Sequence coverage Map3_6K [%]',
#  'Sequence coverage Map3_80K [%]',
#  'Sequence coverage Map3_Cyt [%]',
#  'Sequence coverage [%]',
#  'Sequence length',
#  'Sequence lengths',
#  'Unique + razor sequence coverage [%]',
#  'Unique peptides',
#  'Unique peptides Map1_12K',
#  'Unique peptides Map1_1K',
#  'Unique peptides Map1_24K',
#  'Unique peptides Map1_3K',
#  'Unique peptides Map1_6K',
#  'Unique peptides Map1_80K',
#  'Unique peptides Map1_Cyt',
#  'Unique peptides Map2_12K',
#  'Unique peptides Map2_1K',
#  'Unique peptides Map2_24K',
#  'Unique peptides Map2_3K',
#  'Unique peptides Map2_6K',
#  'Unique peptides Map2_80K',
#  'Unique peptides Map2_Cyt',
#  'Unique peptides Map3_12K',
#  'Unique peptides Map3_1K',
#  'Unique peptides Map3_24K',
#  'Unique peptides Map3_3K',
#  'Unique peptides Map3_6K',
#  'Unique peptides Map3_80K',
#  'Unique peptides Map3_Cyt',
#  'Unique sequence coverage [%]',
#  'iBAQ',
#  'iBAQ Map1_12K',
#  'iBAQ Map1_1K',
#  'iBAQ Map1_24K',
#  'iBAQ Map1_3K',
#  'iBAQ Map1_6K',
#  'iBAQ Map1_80K',
#  'iBAQ Map1_Cyt',
#  'iBAQ Map2_12K',
#  'iBAQ Map2_1K',
#  'iBAQ Map2_24K',
#  'iBAQ Map2_3K',
#  'iBAQ Map2_6K',
#  'iBAQ Map2_80K',
#  'iBAQ Map2_Cyt',
#  'iBAQ Map3_12K',
#  'iBAQ Map3_1K',
#  'iBAQ Map3_24K',
#  'iBAQ Map3_3K',
#  'iBAQ Map3_6K',
#  'iBAQ Map3_80K',
#  'iBAQ Map3_Cyt',
#  'id'}
