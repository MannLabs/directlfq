# %%
# %reload_ext autoreload

# %autoreload 2

# %%
iq_quant_table = "/Users/constantin/workspace/iq/run_datasets/iq_formatted_quant_table_bruderer_15.tsv"
iq_proteins = "/Users/constantin/workspace/iq/run_datasets/iq_formatted_proteins_bruderer_15.tsv"
iq_samples = "/Users/constantin/workspace/iq/run_datasets/iq_formatted_sample_bruderer_15.tsv"
iq_ions = "/Users/constantin/workspace/iq/run_datasets/iq_formatted_ions_bruderer_15.tsv"

# %%
import pandas as pd

quant_df = pd.read_csv(iq_quant_table, sep = "\t")
sample_df = pd.read_csv(iq_samples, sep = "\t").rename(columns={'V1' : 'sample_list'})

display(quant_df)
display(sample_df)
# Out:
#          protein_list  sample_list      id        quant
# 0                   1            1       1  1750.157715
# 1                   1            1       2  1747.151489
# 2                   1            1       3   408.697601
# 3                   1            1       4   431.622864
# 4                   1            1       5  1749.627075
# ...               ...          ...     ...          ...
# 3390564          3544           24  139860  1278.383000
# 3390565          3544           24  139861    84.356860
# 3390566          3544           24  139862  1011.941000
# 3390567          3544           24  139863  2958.586000
# 3390568          3544           24  139864  1173.470000
#
# [3390569 rows x 4 columns]
#                            sample_list
# 0   B_D140314_SGSDSsample1_R01_MHRM_T0
# 1   B_D140314_SGSDSsample1_R02_MHRM_T0
# 2   B_D140314_SGSDSsample1_R03_MHRM_T0
# 3   B_D140314_SGSDSsample2_R01_MHRM_T0
# 4   B_D140314_SGSDSsample2_R02_MHRM_T0
# ...

# %%
import directlfq.benchmarking as lfq_benchmark


input_scaler = lfq_benchmark.ScaledDFCreatorIQFormat(quant_df=quant_df, sample_list_df=sample_df, desired_number_of_samples = 50)

display(input_scaler.scaled_quant_df)
display(input_scaler.scaled_sample_list_df)
# Out:
#          protein_list      id        quant  sample_list
# 0                   1       1  1750.157715            1
# 1                   1       2  1747.151489            1
# 2                   1       3   408.697601            1
# 3                   1       4   431.622864            1
# 4                   1       5  1749.627075            1
# ...               ...     ...          ...          ...
# 7063025          3544  139860  1372.943000           50
# 7063026          3544  139861   610.945700           50
# 7063027          3544  139862  1535.132000           50
# 7063028          3544  139863   899.227800           50
# 7063029          3544  139864  1003.080000           50
#
# [7063030 rows x 4 columns]
#                                          sample_list
# 0           B_D140314_SGSDSsample1_R01_MHRM_T0_AND_0
# 1           B_D140314_SGSDSsample1_R02_MHRM_T0_AND_0
# 2           B_D140314_SGSDSsample1_R03_MHRM_T0_AND_0
# ...
